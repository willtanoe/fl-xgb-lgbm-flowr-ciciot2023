# %% [markdown]
# # 05 - Federated Learning Training (Round Robin)
#
# ## Overview
#
# Train FL models using **Round Robin** strategy with incremental XGBoost/LightGBM.
# Each round: 1 client trains + evaluates. Global model accumulates trees round by round.
#
# **NOTE**: Set `TRAIN_SUBSAMPLE_RATIO = 0.25` in `src/config.py` for 25% data (faster).
# Set to `1.0` for full training once hyperparameters are settled.

# %%
# Imports
import numpy as np
import pandas as pd
import os
import json
import time
import subprocess
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.insert(0, '/home/willtanoe/Documents/fl-xgb-thesis')
from src.config import (
    NUM_CLIENTS, FL_ROUNDS, LOCAL_EPOCHS, FRACTION_FIT,
    XGB_PARAMS, LGB_PARAMS, SEED
)

import flwr as fl

import joblib
from sklearn.metrics import f1_score, accuracy_score, classification_report
from tqdm import tqdm

# Paths
PREPROCESSED_DIR = "/home/willtanoe/Documents/fl-xgb-thesis/results/preprocessed"
CLIENTS_DIR = "/home/willtanoe/Documents/fl-xgb-thesis/results/clients"
MODELS_DIR = "/home/willtanoe/Documents/fl-xgb-thesis/results/models"
LOGS_DIR = "/home/willtanoe/Documents/fl-xgb-thesis/results/logs"

os.makedirs(MODELS_DIR, exist_ok=True)

# Load metadata
with open(os.path.join(PREPROCESSED_DIR, "metadata.json"), 'r') as f:
    metadata = json.load(f)

feature_cols = metadata['feature_cols']
num_classes = metadata['num_classes']

print(f"FL Training Configuration:")
print(f"  Num clients: {NUM_CLIENTS}")
print(f"  FL rounds: {FL_ROUNDS}")
print(f"  Local epochs: {LOCAL_EPOCHS}")
print(f"  Fraction fit: {FRACTION_FIT}")
print(f"  Num classes: {num_classes}")
# Out:
# FL Training Configuration:
#   Num clients: 5
#   FL rounds: 10
#   Local epochs: 5
#   Fraction fit: 1.0
#   Num classes: 34

# %% [markdown]
# ## 1. Define Flower Strategy

# %%
print("Strategy defined in flwr_app/server_app.py via server_fn()")
# Out:
# Strategy defined in flwr_app/server_app.py via server_fn()

# %% [markdown]
# ## 2. Load Validation Data for Centralized Evaluation

# %%
# Load validation and test sets
print("Loading validation and test sets...")
val_df = pd.read_parquet(os.path.join(PREPROCESSED_DIR, "val.parquet"))
test_df = pd.read_parquet(os.path.join(PREPROCESSED_DIR, "test.parquet"))

X_val = val_df[feature_cols].values
y_val = val_df['label'].values
X_test = test_df[feature_cols].values
y_test = test_df['label'].values

print(f"Val: {X_val.shape}, Test: {X_test.shape}")

# Load label encoder for class names
le = joblib.load(os.path.join(PREPROCESSED_DIR, "label_encoder.pkl"))
# Out:
# Loading validation and test sets...
# Val: (1176851, 43), Test: (1176851, 43)

# %%
# Save a 10k sample of val set for Flower App (avoids loading 1.1M rows per actor)
val_sample = val_df.sample(n=min(10000, len(val_df)), random_state=42)
val_sample.to_parquet(os.path.join(PREPROCESSED_DIR, "val_sample.parquet"))
print(f"Saved val_sample.parquet ({len(val_sample)} rows) for Flower App eval")
# Out:
# Saved val_sample.parquet (10000 rows) for Flower App eval

# %% [markdown]
# ## 3. XGBoost FL Training

# %%
PROJECT_DIR = "/home/willtanoe/Documents/fl-xgb-thesis"
FLWR_APP = os.path.join(PROJECT_DIR, "flwr_app")
LOGS_DIR = os.path.join(PROJECT_DIR, "results", "logs")
import subprocess as sp
xgb_log_path = os.path.join(LOGS_DIR, "xgb_flwr_run.log")
os.makedirs(LOGS_DIR, exist_ok=True)

print("Running XGBoost FL training via flwr run...")
print(f"Clients: {NUM_CLIENTS}, Rounds: {FL_ROUNDS}\n")
print(f"Logging to {xgb_log_path}\n")

with open(xgb_log_path, "w") as log_f:
    proc = sp.Popen(
        ["flwr", "run", FLWR_APP, "--stream",
         "--federation-config",
         "client-resources-num-cpus=1 num-supernodes=5"],
        stdout=sp.PIPE, stderr=sp.STDOUT,
        cwd=PROJECT_DIR,
        bufsize=1, universal_newlines=True,
    )
    for line in proc.stdout:
        print(line, end="")
        log_f.write(line)
    proc.wait()

print("\nXGBoost FL training complete.")
# Out:
# Running XGBoost FL training via flwr run...
# Clients: 5, Rounds: 10
#
# Logging to /home/willtanoe/Documents/fl-xgb-thesis/results/logs/xgb_flwr_run.log
#
# Flower App configuration warnings in '/home/willtanoe/Documents/fl-xgb-thesis/flwr_app/pyproject.toml':
# - Recommended property "license" missing in [project]
# 🎊 Successfully started run 7119145565132046282
# INFO :      Starting logstream for run_id `7119145565132046282`
# INFO :      Starting Flower Simulation
# Successfully installed fl-xgb-thesis to /home/willtanoe/.flwr/apps/thesis.fl-xgb-thesis.1.0.0.79b3771b.
#
# ============================================================
# ROUND-ROBIN FL — XGB (10 rounds, +20 trees per round = 200 total)
# ============================================================
# INFO :      Starting Flower ServerApp, config: num_rounds=10, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/opentelemetry/util/_importlib_metadata.py:32: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   return EntryPoints(ep for group_eps in eps.values() for ep in group_eps)
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/ray/_private/worker.py:2051: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (ClientAppActor pid=32030) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=32030)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=32030) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=32030)   parse = parser.parseString(pattern)
# (ClientAppActor pid=32030) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=32030)   parser.resetCache()
# WARNING :   Failed to receive initial parameters from the client. Empty initial parameters will be used.
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32030)   └─ [Client 0] XGB fit (round 1, 259422 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 259422 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32030)   └─ [Client 3] XGB eval (round 1) → F1=0.6786, Acc=0.9830
# (ClientAppActor pid=32029) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=32029)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=32029) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=32029)   parse = parser.parseString(pattern)
# (ClientAppActor pid=32029) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=32029)   parser.resetCache()
# (ClientAppActor pid=32003) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=32003)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=32003) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=32003)   parse = parser.parseString(pattern)
# (ClientAppActor pid=32003) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=32003)   parser.resetCache()
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 1 (20 trees): F1=0.6786, Acc=0.9830
#     └─ ClientEval 0: F1=0.6786, Acc=0.9830 (10000 samples)
#     └─ ClientEval 1: F1=0.6786, Acc=0.9830 (10000 samples)
#     └─ ClientEval 2: F1=0.6786, Acc=0.9830 (10000 samples)
#     └─ ClientEval 3: F1=0.6786, Acc=0.9830 (10000 samples)
#     └─ ClientEval 4: F1=0.6786, Acc=0.9830 (10000 samples)
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32019)   └─ [Client 0] XGB fit (round 2, 259422 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 259422 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32029)   └─ [Client 0] XGB eval (round 2) → F1=0.7024, Acc=0.9851 [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 2 (40 trees): F1=0.7024, Acc=0.9851
#     └─ ClientEval 0: F1=0.7024, Acc=0.9851 (10000 samples)
#     └─ ClientEval 1: F1=0.7024, Acc=0.9851 (10000 samples)
#     └─ ClientEval 2: F1=0.7024, Acc=0.9851 (10000 samples)
#     └─ ClientEval 3: F1=0.7024, Acc=0.9851 (10000 samples)
#     └─ ClientEval 4: F1=0.7024, Acc=0.9851 (10000 samples)
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32003)   └─ [Client 4] XGB fit (round 3, 334623 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 334623 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32028)   └─ [Client 4] XGB eval (round 3) → F1=0.7130, Acc=0.9904 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 3 (60 trees): F1=0.7130, Acc=0.9904
#     └─ ClientEval 0: F1=0.7130, Acc=0.9904 (10000 samples)
#     └─ ClientEval 1: F1=0.7130, Acc=0.9904 (10000 samples)
#     └─ ClientEval 2: F1=0.7130, Acc=0.9904 (10000 samples)
#     └─ ClientEval 3: F1=0.7130, Acc=0.9904 (10000 samples)
#     └─ ClientEval 4: F1=0.7130, Acc=0.9904 (10000 samples)
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32029)   └─ [Client 0] XGB fit (round 4, 259422 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 259422 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32028)   └─ [Client 0] XGB eval (round 4) → F1=0.7076, Acc=0.9882 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 4 (80 trees): F1=0.7076, Acc=0.9882
#     └─ ClientEval 0: F1=0.7076, Acc=0.9882 (10000 samples)
#     └─ ClientEval 1: F1=0.7076, Acc=0.9882 (10000 samples)
#     └─ ClientEval 2: F1=0.7076, Acc=0.9882 (10000 samples)
#     └─ ClientEval 3: F1=0.7076, Acc=0.9882 (10000 samples)
#     └─ ClientEval 4: F1=0.7076, Acc=0.9882 (10000 samples)
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32003)   └─ [Client 4] XGB fit (round 5, 334623 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 334623 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 5 (100 trees): F1=0.7181, Acc=0.9909
#     └─ ClientEval 0: F1=0.7181, Acc=0.9909 (10000 samples)
#     └─ ClientEval 1: F1=0.7181, Acc=0.9909 (10000 samples)
#     └─ ClientEval 2: F1=0.7181, Acc=0.9909 (10000 samples)
#     └─ ClientEval 3: F1=0.7181, Acc=0.9909 (10000 samples)
#     └─ ClientEval 4: F1=0.7181, Acc=0.9909 (10000 samples)
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32028)   └─ [Client 3] XGB eval (round 5) → F1=0.7181, Acc=0.9909 [repeated 5x across cluster]
# (ClientAppActor pid=32028)   └─ [Client 4] XGB fit (round 6, 334623 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 334623 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 6 (120 trees): F1=0.7476, Acc=0.9909
#     └─ ClientEval 0: F1=0.7476, Acc=0.9909 (10000 samples)
#     └─ ClientEval 1: F1=0.7476, Acc=0.9909 (10000 samples)
#     └─ ClientEval 2: F1=0.7476, Acc=0.9909 (10000 samples)
#     └─ ClientEval 3: F1=0.7476, Acc=0.9909 (10000 samples)
#     └─ ClientEval 4: F1=0.7476, Acc=0.9909 (10000 samples)
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32028)   └─ [Client 3] XGB eval (round 6) → F1=0.7476, Acc=0.9909 [repeated 5x across cluster]
# (ClientAppActor pid=32029)   └─ [Client 0] XGB fit (round 7, 259422 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 259422 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32019)   └─ [Client 0] XGB eval (round 7) → F1=0.7211, Acc=0.9897 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 7 (140 trees): F1=0.7211, Acc=0.9897
#     └─ ClientEval 0: F1=0.7211, Acc=0.9897 (10000 samples)
#     └─ ClientEval 1: F1=0.7211, Acc=0.9897 (10000 samples)
#     └─ ClientEval 2: F1=0.7211, Acc=0.9897 (10000 samples)
#     └─ ClientEval 3: F1=0.7211, Acc=0.9897 (10000 samples)
#     └─ ClientEval 4: F1=0.7211, Acc=0.9897 (10000 samples)
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32029)   └─ [Client 0] XGB fit (round 8, 259422 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 259422 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 8 (160 trees): F1=0.7167, Acc=0.9889
#     └─ ClientEval 0: F1=0.7167, Acc=0.9889 (10000 samples)
#     └─ ClientEval 1: F1=0.7167, Acc=0.9889 (10000 samples)
#     └─ ClientEval 2: F1=0.7167, Acc=0.9889 (10000 samples)
#     └─ ClientEval 3: F1=0.7167, Acc=0.9889 (10000 samples)
#     └─ ClientEval 4: F1=0.7167, Acc=0.9889 (10000 samples)
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32028)   └─ [Client 3] XGB eval (round 8) → F1=0.7167, Acc=0.9889 [repeated 5x across cluster]
# (ClientAppActor pid=32019)   └─ [Client 0] XGB fit (round 9, 259422 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 259422 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32029)   └─ [Client 0] XGB eval (round 9) → F1=0.7168, Acc=0.9887 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 9 (180 trees): F1=0.7168, Acc=0.9887
#     └─ ClientEval 0: F1=0.7168, Acc=0.9887 (10000 samples)
#     └─ ClientEval 1: F1=0.7168, Acc=0.9887 (10000 samples)
#     └─ ClientEval 2: F1=0.7168, Acc=0.9887 (10000 samples)
#     └─ ClientEval 3: F1=0.7168, Acc=0.9887 (10000 samples)
#     └─ ClientEval 4: F1=0.7168, Acc=0.9887 (10000 samples)
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=32030)   └─ [Client 4] XGB fit (round 10, 334623 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 334623 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=32028)   └─ [Client 3] XGB eval (round 10) → F1=0.7579, Acc=0.9915 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 10 (200 trees): F1=0.7579, Acc=0.9915
#     └─ ClientEval 0: F1=0.7579, Acc=0.9915 (10000 samples)
#     └─ ClientEval 1: F1=0.7579, Acc=0.9915 (10000 samples)
#     └─ ClientEval 2: F1=0.7579, Acc=0.9915 (10000 samples)
#     └─ ClientEval 3: F1=0.7579, Acc=0.9915 (10000 samples)
#     └─ ClientEval 4: F1=0.7579, Acc=0.9915 (10000 samples)
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 215.96s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.983
# INFO :      		round 2: 0.9851
# INFO :      		round 3: 0.9904
# INFO :      		round 4: 0.9882
# INFO :      		round 5: 0.9909
# INFO :      		round 6: 0.9909
# INFO :      		round 7: 0.9897
# INFO :      		round 8: 0.9889
# INFO :      		round 9: 0.9887
# INFO :      		round 10: 0.9915
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.983),
# INFO :      	              (2, 0.9850999999999999),
# INFO :      	              (3, 0.9904),
# INFO :      	              (4, 0.9882),
# INFO :      	              (5, 0.9909000000000001),
# INFO :      	              (6, 0.9909000000000001),
# INFO :      	              (7, 0.9897),
# INFO :      	              (8, 0.9888999999999999),
# INFO :      	              (9, 0.9887),
# INFO :      	              (10, 0.9915)],
# INFO :      	 'f1_macro': [(1, 0.6786290964007895),
# INFO :      	              (2, 0.70236885416521),
# INFO :      	              (3, 0.7129799000170131),
# INFO :      	              (4, 0.707635763214987),
# INFO :      	              (5, 0.7180564191419263),
# INFO :      	              (6, 0.747593050908934),
# INFO :      	              (7, 0.7210527826764805),
# INFO :      	              (8, 0.7167379995834384),
# INFO :      	              (9, 0.7168082874826736),
# INFO :      	              (10, 0.7578737565770218)]}
# INFO :
# (ClientAppActor pid=32030)   └─ [Client 3] XGB eval (round 10) → F1=0.7579, Acc=0.9915 [repeated 4x across cluster]
# (ClientAppActor pid=32019) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of' [repeated 2x across cluster]
# (ClientAppActor pid=32019)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS)) [repeated 2x across cluster]
# (ClientAppActor pid=32019) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string' [repeated 2x across cluster]
# (ClientAppActor pid=32019)   parse = parser.parseString(pattern) [repeated 2x across cluster]
# (ClientAppActor pid=32019) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache' [repeated 2x across cluster]
# (ClientAppActor pid=32019)   parser.resetCache() [repeated 2x across cluster]
# INFO :
#
# XGBoost FL training complete.

# %% [markdown]
# ## 4. LightGBM FL Training

# %%
print("Running LightGBM FL training via flwr run...")
print(f"Clients: {NUM_CLIENTS}, Rounds: {FL_ROUNDS}\n")
lgb_log_path = os.path.join(LOGS_DIR, "lgb_flwr_run.log")
print(f"Logging to {lgb_log_path}\n")

with open(lgb_log_path, "w") as log_f:
    proc = sp.Popen(
        ["flwr", "run", FLWR_APP, "--stream",
         "--federation-config",
         "client-resources-num-cpus=1 num-supernodes=5",
         "--run-config", 'model_type="lgb"'],
        stdout=sp.PIPE, stderr=sp.STDOUT,
        cwd=PROJECT_DIR,
        bufsize=1, universal_newlines=True,
    )
    for line in proc.stdout:
        print(line, end="")
        log_f.write(line)
    proc.wait()

print("\nLightGBM FL training complete.")
# Out:
# Running LightGBM FL training via flwr run...
# Clients: 5, Rounds: 10
#
# Logging to /home/willtanoe/Documents/fl-xgb-thesis/results/logs/lgb_flwr_run.log
#
# Flower App configuration warnings in '/home/willtanoe/Documents/fl-xgb-thesis/flwr_app/pyproject.toml':
# - Recommended property "license" missing in [project]
# 🎊 Successfully started run 1909308048961649470
# INFO :      Starting logstream for run_id `1909308048961649470`
# INFO :      Starting Flower Simulation
#
# ============================================================
# ROUND-ROBIN FL — LGB (10 rounds, +20 trees per round = 200 total)
# ============================================================
# INFO :      Starting Flower ServerApp, config: num_rounds=10, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Requesting initial parameters from one random client
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
#   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#   parse = parser.parseString(pattern)
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#   parser.resetCache()
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/opentelemetry/util/_importlib_metadata.py:32: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   return EntryPoints(ep for group_eps in eps.values() for ep in group_eps)
# /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/ray/_private/worker.py:2051: FutureWarning: Tip: In future versions of Ray, Ray will no longer override accelerator visible devices env var if num_gpus=0 or num_gpus=None (default). To enable this behavior and turn off this error message, set RAY_ACCEL_ENV_VAR_OVERRIDE_ON_ZERO=0
#   warnings.warn(
# (ClientAppActor pid=35611) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=35611)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=35611) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=35611)   parse = parser.parseString(pattern)
# (ClientAppActor pid=35611) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=35611)   parser.resetCache()
# WARNING :   Failed to receive initial parameters from the client. Empty initial parameters will be used.
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35611)   └─ [Client 2] LGB fit (round 1, 260740 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 260740 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35611)   └─ [Client 2] LGB eval (round 1) → F1=0.7440, Acc=0.9826
# (ClientAppActor pid=35620) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=35620)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=35620) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=35620)   parse = parser.parseString(pattern)
# (ClientAppActor pid=35620) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=35620)   parser.resetCache()
# (ClientAppActor pid=35614) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of'
# (ClientAppActor pid=35614)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS))
# (ClientAppActor pid=35614) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
# (ClientAppActor pid=35614)   parse = parser.parseString(pattern)
# (ClientAppActor pid=35614) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
# (ClientAppActor pid=35614)   parser.resetCache()
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 1 (20 trees): F1=0.7440, Acc=0.9826
#     └─ ClientEval 0: F1=0.7440, Acc=0.9826 (10000 samples)
#     └─ ClientEval 1: F1=0.7440, Acc=0.9826 (10000 samples)
#     └─ ClientEval 2: F1=0.7440, Acc=0.9826 (10000 samples)
#     └─ ClientEval 3: F1=0.7440, Acc=0.9826 (10000 samples)
#     └─ ClientEval 4: F1=0.7440, Acc=0.9826 (10000 samples)
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 2] LGB fit (round 2, 260740 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 260740 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 2] LGB eval (round 2) → F1=0.7484, Acc=0.9857 [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 2 (40 trees): F1=0.7484, Acc=0.9857
#     └─ ClientEval 0: F1=0.7484, Acc=0.9857 (10000 samples)
#     └─ ClientEval 1: F1=0.7484, Acc=0.9857 (10000 samples)
#     └─ ClientEval 2: F1=0.7484, Acc=0.9857 (10000 samples)
#     └─ ClientEval 3: F1=0.7484, Acc=0.9857 (10000 samples)
#     └─ ClientEval 4: F1=0.7484, Acc=0.9857 (10000 samples)
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35592)   └─ [Client 2] LGB fit (round 3, 260740 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 260740 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 1] LGB eval (round 3) → F1=0.7527, Acc=0.9866 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 3 (60 trees): F1=0.7527, Acc=0.9866
#     └─ ClientEval 0: F1=0.7527, Acc=0.9866 (10000 samples)
#     └─ ClientEval 1: F1=0.7527, Acc=0.9866 (10000 samples)
#     └─ ClientEval 2: F1=0.7527, Acc=0.9866 (10000 samples)
#     └─ ClientEval 3: F1=0.7527, Acc=0.9866 (10000 samples)
#     └─ ClientEval 4: F1=0.7527, Acc=0.9866 (10000 samples)
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35592)   └─ [Client 2] LGB fit (round 4, 260740 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 260740 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 2] LGB eval (round 4) → F1=0.7497, Acc=0.9864 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 4 (80 trees): F1=0.7497, Acc=0.9864
#     └─ ClientEval 0: F1=0.7497, Acc=0.9864 (10000 samples)
#     └─ ClientEval 1: F1=0.7497, Acc=0.9864 (10000 samples)
#     └─ ClientEval 2: F1=0.7497, Acc=0.9864 (10000 samples)
#     └─ ClientEval 3: F1=0.7497, Acc=0.9864 (10000 samples)
#     └─ ClientEval 4: F1=0.7497, Acc=0.9864 (10000 samples)
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35614)   └─ [Client 1] LGB fit (round 5, 174669 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 174669 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35615)   └─ [Client 1] LGB eval (round 5) → F1=0.7550, Acc=0.9861 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 5 (100 trees): F1=0.7550, Acc=0.9861
#     └─ ClientEval 0: F1=0.7550, Acc=0.9861 (10000 samples)
#     └─ ClientEval 1: F1=0.7550, Acc=0.9861 (10000 samples)
#     └─ ClientEval 2: F1=0.7550, Acc=0.9861 (10000 samples)
#     └─ ClientEval 3: F1=0.7550, Acc=0.9861 (10000 samples)
#     └─ ClientEval 4: F1=0.7550, Acc=0.9861 (10000 samples)
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35611)   └─ [Client 2] LGB fit (round 6, 260740 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 260740 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35614)   └─ [Client 1] LGB eval (round 6) → F1=0.7760, Acc=0.9897 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 6 (120 trees): F1=0.7760, Acc=0.9897
#     └─ ClientEval 0: F1=0.7760, Acc=0.9897 (10000 samples)
#     └─ ClientEval 1: F1=0.7760, Acc=0.9897 (10000 samples)
#     └─ ClientEval 2: F1=0.7760, Acc=0.9897 (10000 samples)
#     └─ ClientEval 3: F1=0.7760, Acc=0.9897 (10000 samples)
#     └─ ClientEval 4: F1=0.7760, Acc=0.9897 (10000 samples)
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35592)   └─ [Client 1] LGB fit (round 7, 174669 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 174669 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 1] LGB eval (round 7) → F1=0.7335, Acc=0.9862 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 7 (140 trees): F1=0.7335, Acc=0.9862
#     └─ ClientEval 0: F1=0.7335, Acc=0.9862 (10000 samples)
#     └─ ClientEval 1: F1=0.7335, Acc=0.9862 (10000 samples)
#     └─ ClientEval 2: F1=0.7335, Acc=0.9862 (10000 samples)
#     └─ ClientEval 3: F1=0.7335, Acc=0.9862 (10000 samples)
#     └─ ClientEval 4: F1=0.7335, Acc=0.9862 (10000 samples)
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35615)   └─ [Client 1] LGB fit (round 8, 174669 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 174669 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35611)   └─ [Client 2] LGB eval (round 8) → F1=0.7340, Acc=0.9858 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 8 (160 trees): F1=0.7340, Acc=0.9858
#     └─ ClientEval 0: F1=0.7340, Acc=0.9858 (10000 samples)
#     └─ ClientEval 1: F1=0.7340, Acc=0.9858 (10000 samples)
#     └─ ClientEval 2: F1=0.7340, Acc=0.9858 (10000 samples)
#     └─ ClientEval 3: F1=0.7340, Acc=0.9858 (10000 samples)
#     └─ ClientEval 4: F1=0.7340, Acc=0.9858 (10000 samples)
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 2] LGB fit (round 9, 260740 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 260740 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35615)   └─ [Client 2] LGB eval (round 9) → F1=0.7517, Acc=0.9907 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 9 (180 trees): F1=0.7517, Acc=0.9907
#     └─ ClientEval 0: F1=0.7517, Acc=0.9907 (10000 samples)
#     └─ ClientEval 1: F1=0.7517, Acc=0.9907 (10000 samples)
#     └─ ClientEval 2: F1=0.7517, Acc=0.9907 (10000 samples)
#     └─ ClientEval 3: F1=0.7517, Acc=0.9907 (10000 samples)
#     └─ ClientEval 4: F1=0.7517, Acc=0.9907 (10000 samples)
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 1 clients (out of 5)
# (ClientAppActor pid=35620)   └─ [Client 1] LGB fit (round 10, 174669 samples, +20 trees)
# INFO :      aggregate_fit: received 1 results and 0 failures
#   └─ Global model updated (+20 trees, 174669 samples)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=35611)   └─ [Client 1] LGB eval (round 10) → F1=0.7378, Acc=0.9868 [repeated 5x across cluster]
# INFO :      aggregate_evaluate: received 5 results and 0 failures
#   Round 10 (200 trees): F1=0.7378, Acc=0.9868
#     └─ ClientEval 0: F1=0.7378, Acc=0.9868 (10000 samples)
#     └─ ClientEval 1: F1=0.7378, Acc=0.9868 (10000 samples)
#     └─ ClientEval 2: F1=0.7378, Acc=0.9868 (10000 samples)
#     └─ ClientEval 3: F1=0.7378, Acc=0.9868 (10000 samples)
#     └─ ClientEval 4: F1=0.7378, Acc=0.9868 (10000 samples)
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 10 round(s) in 303.05s
# INFO :      	History (loss, distributed):
# INFO :      		round 1: 0.9826
# INFO :      		round 2: 0.9857
# INFO :      		round 3: 0.9866
# INFO :      		round 4: 0.9864
# INFO :      		round 5: 0.9861
# INFO :      		round 6: 0.9897
# INFO :      		round 7: 0.9862
# INFO :      		round 8: 0.9858
# INFO :      		round 9: 0.9907
# INFO :      		round 10: 0.9868
# INFO :      	History (metrics, distributed, evaluate):
# INFO :      	{'accuracy': [(1, 0.9826),
# INFO :      	              (2, 0.9856999999999999),
# INFO :      	              (3, 0.9865999999999999),
# INFO :      	              (4, 0.9864),
# INFO :      	              (5, 0.9861000000000001),
# INFO :      	              (6, 0.9897),
# INFO :      	              (7, 0.9862),
# INFO :      	              (8, 0.9858),
# INFO :      	              (9, 0.9907),
# INFO :      	              (10, 0.9868)],
# INFO :      	 'f1_macro': [(1, 0.7439698850025768),
# INFO :      	              (2, 0.7483717983406452),
# INFO :      	              (3, 0.7526973292879349),
# INFO :      	              (4, 0.7497220051195732),
# INFO :      	              (5, 0.7550388776339989),
# INFO :      	              (6, 0.7760471767593088),
# INFO :      	              (7, 0.7335161235560334),
# INFO :      	              (8, 0.7339923470664017),
# INFO :      	              (9, 0.7516707586739886),
# INFO :      	              (10, 0.7377811454595491)]}
# INFO :
# (ClientAppActor pid=35592)   └─ [Client 2] LGB eval (round 10) → F1=0.7378, Acc=0.9868 [repeated 4x across cluster]
# (ClientAppActor pid=35592) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:64: PyparsingDeprecationWarning: 'oneOf' deprecated - use 'one_of' [repeated 2x across cluster]
# (ClientAppActor pid=35592)   prop = Group((name + Suppress("=") + comma_separated(value)) | oneOf(_CONSTANTS)) [repeated 2x across cluster]
# (ClientAppActor pid=35592) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:85: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string' [repeated 2x across cluster]
# (ClientAppActor pid=35592)   parse = parser.parseString(pattern) [repeated 2x across cluster]
# (ClientAppActor pid=35592) /home/willtanoe/micromamba/envs/vel/lib/python3.10/site-packages/matplotlib/_fontconfig_pattern.py:89: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache' [repeated 2x across cluster]
# (ClientAppActor pid=35592)   parser.resetCache() [repeated 2x across cluster]
# INFO :
#
# LightGBM FL training complete.

# %% [markdown]
# ## 5. Save Training History

# %%
# Load metrics from flwr run output files
xgb_metrics_path = os.path.join(LOGS_DIR, "fl_history_xgb.json")
lgb_metrics_path = os.path.join(LOGS_DIR, "fl_history_lgb.json")

xgb_data = {}
lgb_data = {}

if os.path.exists(xgb_metrics_path):
    with open(xgb_metrics_path) as f:
        xgb_data = json.load(f)
    print(f"Loaded XGBoost metrics: {len(xgb_data.get('rounds', []))} rounds")

if os.path.exists(lgb_metrics_path):
    with open(lgb_metrics_path) as f:
        lgb_data = json.load(f)
    print(f"Loaded LightGBM metrics: {len(lgb_data.get('rounds', []))} rounds")

# Build history objects for backward compat with plotting code
class MockHistory:
    def __init__(self, data):
        self.metrics_distributed = {}
        if data.get("f1_macro"):
            rounds = data.get("rounds", [])
            self.metrics_distributed["f1_macro"] = list(zip(rounds, data["f1_macro"]))
        self.losses_distributed = [(r, 0.0) for r in data.get("rounds", [])]

history = MockHistory(xgb_data)
history_lgb = MockHistory(lgb_data)

# Save combined history (backwards compat)
history_data = {
    'xgb': {
        'rounds': xgb_data.get('rounds', []),
        'f1_macro': xgb_data.get('f1_macro', []),
        'accuracy': xgb_data.get('accuracy', []),
    },
    'lgb': {
        'rounds': lgb_data.get('rounds', []),
        'f1_macro': lgb_data.get('f1_macro', []),
        'accuracy': lgb_data.get('accuracy', []),
    },
    'config': {
        'num_clients': NUM_CLIENTS,
        'fl_rounds': FL_ROUNDS,
        'num_classes': num_classes,
    }
}

with open(os.path.join(LOGS_DIR, 'fl_training_history.json'), 'w') as f:
    json.dump(history_data, f, indent=2)
print("Training history saved: results/logs/fl_training_history.json")
# Out:
# Loaded XGBoost metrics: 10 rounds
# Loaded LightGBM metrics: 10 rounds
# Training history saved: results/logs/fl_training_history.json

# %% [markdown]
# ## 6. Plot Training Curves

# %%
import matplotlib.pyplot as plt

# Plot training curves
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# XGBoost
ax = axes[0]
if xgb_data.get('f1_macro'):
    ax.plot(xgb_data['rounds'], xgb_data['f1_macro'], 'b-', label='XGBoost F1 Macro')
    ax.plot(xgb_data['rounds'], xgb_data['accuracy'], 'b--', label='XGBoost Accuracy')
ax.set_xlabel('FL Round')
ax.set_ylabel('Score')
ax.set_title('XGBoost Training')
ax.legend()
ax.grid(True, alpha=0.3)

# LightGBM
ax = axes[1]
if lgb_data.get('f1_macro'):
    ax.plot(lgb_data['rounds'], lgb_data['f1_macro'], 'orange', label='LightGBM F1 Macro')
    ax.plot(lgb_data['rounds'], lgb_data['accuracy'], 'orange', ls='--', label='LightGBM Accuracy')
ax.set_xlabel('FL Round')
ax.set_ylabel('Score')
ax.set_title('LightGBM Training')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig(os.path.join(LOGS_DIR, '05_fl_training_curves.png'), dpi=150, bbox_inches='tight')
plt.show()

print("Figure saved: results/logs/05_fl_training_curves.png")
# Out:
# Figure saved: results/logs/05_fl_training_curves.png

# %% [markdown]
# ## Summary
#
# - Trained XGBoost with FedAvg for {FL_ROUNDS} rounds
# - Trained LightGBM with FedAvg for {FL_ROUNDS} rounds
# - Client/Server logic defined in `flwr_app/` (ClientApp + ServerApp)
# - Training history saved to `results/logs/fl_training_history.json`
#
# **Next**: Run `06_evaluation.ipynb` for full evaluation on test set.
